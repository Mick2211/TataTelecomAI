# %% [markdown]
# # Python Advanced - Data Science Foundation
#
# **SET THE WORKING DIRECTORY SO THAT WE DO NOT HAVE TO THINK ABOUT PATH PROBLEMS**
#
# Please ensure all your folder names <font color='red'><b>do not have a space & use forward slash (/)</b></font>

# %%
your_local_path="D:/Users/nigam.l/Desktop/UPX/Class Materials/Foundation"

# %%
import pandas as pd #this will import pandas into your workspace

# %%
import numpy as np  #we will be using numpy functions so import numpy
% matplotlib inline

# %%
cars = pd.read_csv(your_local_path+'/cars.csv')

# %%
type(cars)
cars.head(20)
# Out:
#                         Model  Actual_MPG  Cylinders  Engine_Disp  Horsepower  \
# 0          amc ambassador dpl        15.0          8        390.0         190
# 1                 amc gremlin        21.0          6        199.0          90
# 2                  amc hornet        18.0          6        199.0          97
# 3               amc rebel sst        16.0          8        304.0         150
# 4     buick estate wagon (sw)        14.0          8        455.0         225
# 5           buick skylark 320        15.0          8        350.0         165
# 6   chevrolet chevelle malibu        18.0          8        307.0         130
# 7            chevrolet impala        14.0          8        454.0         220
# 8       chevrolet monte carlo        15.0          8        400.0         150
# 9                   chevy c20        10.0          8        307.0         200
# 10        dodge challenger se        15.0          8        383.0         170
# 11                 dodge d200        11.0          8        318.0         210
# 12                  ford f250        10.0          8        360.0         215
# 13           ford galaxie 500        15.0          8        429.0         198
# 14              ford maverick        21.0          6        200.0          85
# 15                ford torino        17.0          8        302.0         140
# 16                   hi 1200d         9.0          8        304.0         193
# 17         plymouth 'cuda 340        14.0          8        340.0         160
# 18            plymouth duster        22.0          6        198.0          95
# 19          plymouth fury iii        14.0          8        440.0         215
#
#     Weight  Accelerate  Year    Origin
# 0     3850         8.5    70  American
# 1     2648        15.0    70  American
# 2     2774        15.5    70  American
# 3     3433        12.0    70  American
# 4     3086        10.0    70  American
# 5     3693        11.5    70  American
# 6     3504        12.0    70  American
# 7     4354         9.0    70  American
# 8     3761         9.5    70  American
# 9     4376        15.0    70  American
# 10    3563        10.0    70  American
# 11    4382        13.5    70  American
# 12    4615        14.0    70  American
# 13    4341        10.0    70  American
# 14    2587        16.0    70  American
# 15    3449        10.5    70  American
# 16    4732        18.5    70  American
# 17    3609         8.0    70  American
# 18    2833        15.5    70  American
# 19    4312         8.5    70  American

# %%
carsgrp = cars.groupby('Cylinders').mean()     # Data GROUP BY
carsgrp2 = cars.groupby('Cylinders')
carsgrp
#round(carsgrp,2)
# Out:
#            Actual_MPG  Engine_Disp  Horsepower       Weight  Accelerate  \
# Cylinders
# 3           20.550000    72.500000   99.250000  2398.500000   13.250000
# 4           29.283920   109.670854   78.281407  2305.110553   16.581910
# 5           27.366667   145.000000   82.333333  3103.333333   18.633333
# 6           19.973494   218.361446  101.506024  3202.120482   16.254217
# 8           14.963107   345.009709  158.300971  4114.718447   12.955340
#
#                 Year
# Cylinders
# 3          75.500000
# 4          77.030151
# 5          79.000000
# 6          75.951807
# 8          73.902913

# %%
cars.describe()
# Out:
#        Actual_MPG   Cylinders  Engine_Disp  Horsepower       Weight  \
# count  392.000000  392.000000   392.000000  392.000000   392.000000
# mean    23.445918    5.471939   194.411990  104.469388  2977.584184
# std      7.805007    1.705783   104.644004   38.491160   849.402560
# min      9.000000    3.000000    68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000   105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000   151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000   275.750000  126.000000  3614.750000
# max     46.600000    8.000000   455.000000  230.000000  5140.000000
#
#        Accelerate        Year
# count  392.000000  392.000000
# mean    15.541327   75.979592
# std      2.758864    3.683737
# min      8.000000   70.000000
# 25%     13.775000   73.000000
# 50%     15.500000   76.000000
# 75%     17.025000   79.000000
# max     24.800000   82.000000

# %%
cars['Actual_MPG'].hist()

# %%
cars['Engine_Disp'].hist()

# %%
% matplotlib inline 
import seaborn as sb
sb.pairplot(cars, hue = 'Origin', kind="reg")

# %%
import seaborn as sb
sb.pairplot(cars, hue'cy')

# %%
cars['Engine_Disp'].hist()

# %%
# Pivot table demo
table = pd.pivot_table(cars, values='Actual_MPG', index=['Cylinders','Origin'],columns=['Weight','Year'], aggfunc=np.median)
table2 = pd.pivot_table(cars, values=('Actual_MPG','Horsepower'), index=['Origin', 'Cylinders'],columns=['Year'])
#round(table,2)
#print (table)
table2
# Out:
#                    Actual_MPG                                              \
# Year                       70         71         72         73         74
# Origin   Cylinders
# American 4                NaN  24.750000  23.200000  20.000000  26.333333
#          6          20.500000  18.000000        NaN  18.857143  17.333333
#          8          14.111111  13.428571  13.615385  13.200000  14.200000
# European 4          25.200000  28.750000  22.000000  24.000000  27.000000
#          5                NaN        NaN        NaN        NaN        NaN
#          6                NaN        NaN        NaN        NaN        NaN
# Japanese 3                NaN        NaN  19.000000  18.000000        NaN
#          4          25.500000  29.500000  25.500000  21.000000  29.333333
#          6                NaN        NaN        NaN  20.000000        NaN
#
#                                                                         \
# Year                       75         76      77         78         79
# Origin   Cylinders
# American 4          23.000000  26.200000  28.250  28.183333  30.857143
#          6          17.583333  20.562500  18.875  19.560000  22.950000
#          8          15.666667  14.666667  16.000  19.050000  18.630000
# European 4          24.500000  25.357143  29.250  32.066667  32.133333
#          5                NaN        NaN     NaN  20.300000  25.400000
#          6                NaN  16.500000     NaN  16.600000        NaN
# Japanese 3                NaN        NaN  21.500        NaN        NaN
#          4          27.500000  31.000000  30.250  29.687500  32.950000
#          6                NaN  19.000000  22.000        NaN        NaN
#
#                        ...      Horsepower                                  \
# Year                   ...              73          74      75          76
# Origin   Cylinders     ...
# American 4             ...       78.500000   76.666667   80.50   71.000000
#          6             ...       99.285714  101.666667   96.75   94.875000
#          8             ...      170.000000  146.000000  142.00  146.333333
# European 4             ...       81.857143   74.166667   89.50   83.000000
#          5             ...             NaN         NaN     NaN         NaN
#          6             ...             NaN         NaN     NaN  120.000000
# Japanese 3             ...       90.000000         NaN     NaN         NaN
#          4             ...       91.000000   72.500000   80.25   66.000000
#          6             ...      122.000000         NaN     NaN  108.000000
#
#                                                                              \
# Year                        77          78          79          80       81
# Origin   Cylinders
# American 4           83.166667   81.166667   81.142857   88.600000   75.125
#          6          103.250000  106.000000  105.000000   90.000000   98.250
#          8          152.375000  135.500000  131.900000         NaN  105.000
# European 4           81.000000   78.000000   70.333333   66.714286   77.000
#          5                 NaN  103.000000   77.000000   67.000000      NaN
#          6                 NaN  129.000000         NaN         NaN   76.000
# Japanese 3          110.000000         NaN         NaN  100.000000      NaN
#          4           70.000000   79.250000   65.000000   72.090909   70.400
#          6           97.000000         NaN         NaN  132.000000  118.000
#
#
# Year                        82
# Origin   Cylinders
# American 4           84.062500
#          6          102.333333
#          8                 NaN
# European 4           63.000000
#          5                 NaN
#          6                 NaN
# Japanese 3                 NaN
#          4           74.000000
#          6                 NaN
#
# [9 rows x 26 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
% matplotlib inline

# %%
#scatter plots
# first let's create a x variable
plt.scatter(cars.Weight,cars.Actual_MPG,color ='purple')
#plt.plot(cars.Actual_MPG,color ='purple')
plt.xlabel ('Weight')
plt.ylabel ('Actual_MPG')
plt.show()

# %%
#scatter plots
plt.plot(carsgrp.Horsepower,carsgrp.Actual_MPG,'b',linestyle = '--',color ='red', linewidth = 4.5)
#plt.plot(carsgrp.Horsepower,carsgrp.Actual_MPG)
plt.xlabel ('Horsepower')
plt.ylabel ('Actual_MPG')
plt.title ('Horsepower vs MPG Trend')
plt.show()

# %%
#left # the left side of the subplots of the figure
#right # the right side of the subplots of the figure
#bottom # the bottom of the subplots of the figure
#top # the top of the subplots of the figure
#wspace # the amount of width reserved for blank space between subplots
#hspace # the amount of height reserved for white space between subplots'''
plt.figure(figsize=(20,10))
plt.subplots_adjust(hspace= 0.2, wspace= 0.2)
plt.subplot(2,2,1)
plt.title ('Actual_MPG')
plt.plot(cars.Actual_MPG,'r')
plt.subplot(2,2,2)
plt.title ('Weight')
plt.plot(cars.Weight, 'b')
plt.subplot(2,2,3)
plt.title ('Cylinders')
plt.plot(cars.Cylinders, 'g')
plt.subplot(2,2,4)
plt.title ('Horsepower')
plt.plot(cars.Horsepower,'y')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust( wspace= 0.5)
plt.subplot(1,4,1)
plt.title ('Actual_MPG')
plt.plot(cars.Actual_MPG,'r')
plt.subplot(1,4,2)
plt.title ('Weight')
plt.plot(cars.Weight, 'b')
plt.subplot(1,4,3)
plt.title ('Cylinders')
plt.plot(cars.Cylinders, 'g')
plt.subplot(1,4,4)
plt.title ('Horsepower')
plt.plot(cars.Horsepower,'y')

# %%
# Scatter Plot
# color pallete- http://seaborn.pydata.org/tutorial/color_palettes.html
import seaborn as sns
iris = sns.load_dataset("iris")
print (iris.head())
sns.pairplot(iris, hue="species", palette="husl", size =5)
plt.show()

# %%
sns.boxplot(x='Origin',y='Actual_MPG',data=cars,linewidth=1)
plt.show()

# %%
# Heatmap- first load library and datasets
flight_data = sns.load_dataset("flights")
flight_data.head()
#flight_data.shape

# %%
# rearrange data
flight_data = flight_data.pivot('month','year','passengers')
flight_data

# %%
# generate map
sns.heatmap(flight_data, annot= True, fmt = "d")
plt.show()

# %%
sns.heatmap(flight_data, cmap="YlGnBu")
plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labe = 'Frogs','Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explo = (0, 0, 1, 0)  # only "explode" the 3rd slice (i.e. 'Hogs')

plt.pie(sizes, explode=explo, labels=labe, autopct='%1.1f%%',
        shadow=True)

plt.show()
